# %%
import pokers as pkrs
import random

class RandomAgent:
    """Simple random agent for poker."""
    def __init__(self, player_id):
        self.player_id = player_id
        
    def choose_action(self, state):
        """Choose a random legal action."""
        if not state.legal_actions:
            raise
        
        # Select a random legal action
        action_enum = random.choice(state.legal_actions)
        
        # For raises, select a random amount between min and max
        if action_enum == pkrs.ActionEnum.Raise:
            player_state = state.players_state[state.current_player]
            min_amount = state.min_bet
            max_amount = player_state.stake  # All-in
            
            # Choose between 0.5x pot, 1x pot, or a random amount
            pot_amounts = [state.pot * 0.5, state.pot]
            valid_amounts = [amt for amt in pot_amounts if min_amount <= amt <= max_amount]
            
            if valid_amounts:
                amount = random.choice(valid_amounts)
            else:
                amount = random.uniform(min_amount, max_amount)
                
            return pkrs.Action(action_enum, amount)
        else:
            return pkrs.Action(action_enum)

# %%
agents = [RandomAgent("Player 1"), RandomAgent("Player 2"), RandomAgent("Player 3"), RandomAgent("Player 4"), RandomAgent("Player 5"), RandomAgent("Player 6")]

traces = []

for _ in range(1000):
    initial_state = pkrs.State.from_seed(n_players=len(agents), button=0, sb=0.5, bb=1.0, stake=100.0, seed=random.randint(0, 10000))
    trace = [initial_state]

    while not trace[-1].final_state:
        state = trace[-1]
        print(f"Stage -> {state.stage}")
        print(f"Actions: {state.legal_actions}", end="")
        action = agents[state.current_player].choose_action(state)
        print(f" -> {action}")
        new_state = state.apply_action(action)
        trace.append(new_state)

        trace.append(state.apply_action(action))
    
    traces.append(trace)
# Out:
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10aae2310>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# ...
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Flop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Turn
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.River
# Actions: [ActionEnum.Fold, ActionEnum.Check, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x10675bf90>
# Stage -> Stage.Preflop
# Actions: [ActionEnum.Fold, ActionEnum.Call, ActionEnum.Raise] -> <builtins.Action object at 0x1066f78d0>
# Ranks: [(9, 4, 9535), (9, 4, 2931)]
# Winner id: [1]
# Ranks: [(9, 4, 9535), (9, 4, 2931)]
# Winner id: [1]
# Ranks: [(9, 1, 2399), (8, 23, 31236)]
# Winner id: [1]
# Ranks: [(9, 1, 2399), (8, 23, 31236)]
# Winner id: [1]
# Ranks: [(8, 47, 7210), (9, 4, 4957)]
# Winner id: [0]
# Ranks: [(8, 47, 7210), (9, 4, 4957)]
# Winner id: [0]
# Ranks: [(10, 9718, 0), (9, 12, 66923)]
# Winner id: [1]
# Ranks: [(10, 9718, 0), (9, 12, 66923)]
# Winner id: [1]
# Ranks: [(6, 126342, 0), (6, 126342, 0)]
# Winner id: [0, 1]
# Ranks: [(6, 126342, 0), (6, 126342, 0)]
# Winner id: [0, 1]

# %%
print(traces[0][0])
# Out:
# State {
#     current_player: 3,
#     players_state: [
#         PlayerState {
#             player: 0,
#             hand: (
#                 Card {
#                     suit: Clubs,
#                     rank: R4,
#                 },
#                 Card {
#                     suit: Diamonds,
#                     rank: R6,
#                 },
#             ),
#             bet_chips: 0.0,
#             pot_chips: 0.0,
#             stake: 100.0,
#             reward: 0.0,
#             active: true,
#             last_stage_action: None,
#         },
#         PlayerState {
#             player: 1,
#             hand: (
#                 Card {
#                     suit: Clubs,
#                     rank: RT,
#                 },
#                 Card {
#                     suit: Diamonds,
#                     rank: RT,
#                 },
#             ),
#             bet_chips: 0.5,
#             pot_chips: 0.0,
#             stake: 99.5,
#             reward: 0.0,
#             active: true,
#             last_stage_action: None,
#         },
#         PlayerState {
#             player: 2,
#             hand: (
#                 Card {
#                     suit: Diamonds,
#                     rank: R4,
#                 },
#                 Card {
#                     suit: Hearts,
#                     rank: RJ,
#                 },
#             ),
#             bet_chips: 1.0,
#             pot_chips: 0.0,
#             stake: 99.0,
#             reward: 0.0,
#             active: true,
#             last_stage_action: None,
#         },
#         PlayerState {
#             player: 3,
#             hand: (
#                 Card {
#                     suit: Diamonds,
#                     rank: R7,
#                 },
#                 Card {
#                     suit: Clubs,
#                     rank: R7,
#                 },
#             ),
#             bet_chips: 0.0,
#             pot_chips: 0.0,
#             stake: 100.0,
#             reward: 0.0,
#             active: true,
#             last_stage_action: None,
#         },
#         PlayerState {
#             player: 4,
#             hand: (
#                 Card {
#                     suit: Clubs,
#                     rank: R6,
#                 },
#                 Card {
#                     suit: Spades,
#                     rank: R6,
#                 },
#             ),
#             bet_chips: 0.0,
#             pot_chips: 0.0,
#             stake: 100.0,
#             reward: 0.0,
#             active: true,
#             last_stage_action: None,
#         },
#         PlayerState {
#             player: 5,
#             hand: (
#                 Card {
#                     suit: Hearts,
#                     rank: R6,
#                 },
#                 Card {
#                     suit: Diamonds,
#                     rank: RK,
#                 },
#             ),
#             bet_chips: 0.0,
#             pot_chips: 0.0,
#             stake: 100.0,
#             reward: 0.0,
#             active: true,
#             last_stage_action: None,
#         },
#     ],
#     public_cards: [],
#     stage: Preflop,
#     button: 0,
#     from_action: None,
#     legal_actions: [
#         Fold,
#         Call,
#         Raise,
#     ],
#     deck: [
#         Card {
#             suit: Hearts,
#             rank: R2,
#         },
#         Card {
#             suit: Hearts,
#             rank: RT,
#         },
#         Card {
#             suit: Spades,
#             rank: R5,
#         },
#         Card {
#             suit: Diamonds,
#             rank: R9,
#         },
#         Card {
#             suit: Clubs,
#             rank: R8,
#         },
#         Card {
#             suit: Clubs,
#             rank: RJ,
#         },
#         Card {
#             suit: Hearts,
#             rank: R4,
#         },
#         Card {
#             suit: Spades,
#             rank: R3,
#         },
#         Card {
#             suit: Spades,
#             rank: RT,
#         },
#         Card {
#             suit: Spades,
#             rank: R8,
#         },
#         Card {
#             suit: Clubs,
#             rank: RQ,
#         },
#         Card {
#             suit: Diamonds,
#             rank: R3,
#         },
#         Card {
#             suit: Spades,
#             rank: R2,
#         },
#         Card {
#             suit: Spades,
#             rank: R7,
#         },
#         Card {
#             suit: Hearts,
#             rank: RQ,
#         },
#         Card {
#             suit: Spades,
#             rank: RK,
#         },
#         Card {
#             suit: Hearts,
#             rank: R8,
#         },
#         Card {
#             suit: Hearts,
#             rank: R9,
#         },
#         Card {
#             suit: Spades,
#             rank: R4,
#         },
#         Card {
#             suit: Diamonds,
#             rank: RA,
#         },
#         Card {
#             suit: Diamonds,
#             rank: RQ,
#         },
#         Card {
#             suit: Clubs,
#             rank: R5,
#         },
#         Card {
#             suit: Diamonds,
#             rank: RJ,
#         },
#         Card {
#             suit: Diamonds,
#             rank: R8,
#         },
#         Card {
#             suit: Hearts,
#             rank: R3,
#         },
#         Card {
#             suit: Clubs,
#             rank: R9,
#         },
#         Card {
#             suit: Spades,
#             rank: RJ,
#         },
#         Card {
#             suit: Clubs,
#             rank: R2,
#         },
#         Card {
#             suit: Clubs,
#             rank: RK,
#         },
#         Card {
#             suit: Spades,
#             rank: R9,
#         },
#         Card {
#             suit: Diamonds,
#             rank: R5,
#         },
#         Card {
#             suit: Diamonds,
#             rank: R2,
#         },
#         Card {
#             suit: Hearts,
#             rank: R7,
#         },
#         Card {
#             suit: Clubs,
#             rank: RA,
#         },
#         Card {
#             suit: Hearts,
#             rank: RK,
#         },
#         Card {
#             suit: Spades,
#             rank: RQ,
#         },
#         Card {
#             suit: Clubs,
#             rank: R3,
#         },
#         Card {
#             suit: Hearts,
#             rank: R5,
#         },
#         Card {
#             suit: Spades,
#             rank: RA,
#         },
#         Card {
#             suit: Hearts,
#             rank: RA,
#         },
#     ],
#     pot: 1.5,
#     min_bet: 1.0,
#     final_state: false,
#     status: Ok,
# }

# %%
for trace in traces:
    final_stage = trace[-1]
    print(final_stage.status)
    #print(pkrs.visualize_trace(trace))
# Out:
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.Ok
# StateStatus.HighBet
# StateStatus.HighBet
# StateStatus.Ok
